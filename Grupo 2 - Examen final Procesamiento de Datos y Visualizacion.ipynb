# %% [markdown]
# #✨**Examen Diplomatura en Ciencia de Datos**✨
# ##📊 **Procesamiento de Datos y Visualización de la Información**
# ###***Tercer Bimestre***

# %% [markdown]
# #📈**Análisis de la evolución del Presupuesto Sancionado de CABA 2017-2021**
#
# ##**Objetivo**
#
# El objetivo de nuestro análisis es estudiar la evolución del Presupuesto del Gasto Público sancionado para la Ciudad de Buenos Aires desde 2017 a 2021. Específicamente, nos enfocaremos en la clasificación del gasto por finalidad y función en base a la ubicación geográfica por Comunas. Es decir, responderemos a las preguntas:
# - ***¿Dónde se gasta?***
#   - Barrios ordernados por Comunas
# <br>
# <br>
# - ***¿Para qué se gasta?*** dividido en las siguientes cartegorías (descripción de todas las cuentas [acá](https://recursos-data.buenosaires.gob.ar/ckan2/presupuesto-ejecutado/Glosarios/Glosario%20_Para_qu%C3%A9.pdf)):
#   1. ADMINISTRACIÓN GUBERNAMENTAL:
#    - Legislativa
#     - Judicial
#     - Dirección ejecutiva
#     - Relaciones exteriores
#     - Relaciones interiores
#     - Administración fiscal
#     - Control de la gestión
#   2. SERVICIOS DE SEGURIDAD
#     - Segurdiad pública
#     - Sistema penal
#   3. SERVICIOS SOCIALES:
#     - Salud
#     - Promoción y acción social
#     - Seguridad social
#     - Educación
#     - Cultura
#     - Trabajo
#     - Vivienda
#     - Agua potable y alcantarillado
#   4. SERVICIOS ECONÓMICOS:
#     - Energía, combustibles y minería
#     - Comunicaciones
#     - Transporte
#     - Ecología
#     - Turismo
#     - Industria y Comercio
#     - seguros y Finanzas
#     - Servicios Urbanos
#   5. DEUDA PÚBLICA – INTERESES Y GASTOS
# <br>
# <br>
#
#   De las cuales sólo nos enfocaremos en:
#   - **Salud** (servicios sociales): Son las acciones orientadas a garantizar un óptimo nivel de salud a toda la población. Incluye el gasto que se hace en todos los hospitales y centros de salud de la Ciudad, las campañas de prevención de enfermedades y de vacunación, la compra de equipamiento médico y cualquier otro aspecto que tenga incidencia en la salud.
#
#   - **Educación** (servicios sociales): Incluye las acciones que permitan asegurar a todas las personas el acceso, la permanencia, la reinserción y el egreso del sistema educativo, con una mirada integral e inclusiva. Abarcan también la difusión y enseñanza de todos los aspectos del saber humano dirigidos a satisfacer necesidades del individuo. Es la política pública más importante de la ciudad, y a la que más presupuesto se le asigna.
#
#   - **Vivienda** (servicios sociales): Acciones destinadas a posibilitar a los integrantes de la comunidad el acceso a la vivienda, a través de distintos instrumentos como créditos financieros o planes de ayuda.
#
#   - **Cultura** (servicios sociales): se registran las acciones orientadas a promover desde el sector público todas las manifestaciones culturales e intelectuales, con un criterio amplio y diverso. Abarca los espectáculos públicos culturales, las actividades de radiodifusión, cine, teatros, museos, bibliotecas, monumentos y lugares históricos, así como el cuidado del patrimonio. Incluye también las acciones destinadas a brindar recreación y esparcimiento a la población, así como actividades deportivas y religiosas, que forman parte de nuestra cultura.
#
#   - **Ecología** (servicios económicos): Acciones relacionadas con la preservación e incremento de espacios verdes, áreas parquizadas y forestadas, parques naturales y zonas de reserva ecológica. Comprende también la protección y saneamiento de las áreas costeras y toda acción que haga a la preservación del medio físico, biológico y social del hombre
#
#   - **Transporte** (servicio económico): Acciones destinadas al equipamiento de la red vial de la ciudad, así como a la construcción, conservación, señalización, ordenamiento y fiscalización del tránsito de calles, avenidas, autopistas, túneles, puentes, estaciones, etc. Abarca también todas las las acciones relacionadas con el transporte subterráneo de pasajeros.

# %% [markdown]
# ## **Contexto y Situación Actual**
#
# **Presupuesto Nacional vs Presuesto del Ciudad de Buenos Aires: diferencias**
#
# El Presupuesto Nacional es una ley anual que sanciona el Congreso, donde planifica los ingresos que recibirá el Gobierno y cómo se aplicarán para satisfacer las necesidades de la población: seguridad social, educación, salud, seguridad y justicia, entre otras. Tiene mucha importancia porque permite responder las siguientes preguntas: ¿Cuál es el destino del gasto? ¿En qué se gasta? ¿Quién gasta? ¿Cuál es el origen de los recursos?
# El Presupuesto financia el funcionamiento de todo el Estado Nacional; es decir de los Poderes Ejecutivo, Legislativo y Judicial. También contiene las transferencias que se realizan a los estados provinciales y municipales quienes a su vez confeccionan sus propios presupuestos.”
#
# Fuente: https://www.economia.gob.ar/onp/presupuesto_ciudadano/seccion1.php
#
# El Presupuesto Nacional se discute y aprueba en el Congreso de la Nación (diputados y senadores) como proyecto de Ley. En cambio, el presupuesto de la Ciudad de Buenos Aires se sanciona en la Legislatura de la Ciudad de Buenos Aires (legisladores).
#
# Actualmente, la Legislatura de la Ciudad de Buenos Aires se compone de la siguiente forma:
# ![image.png](data:image/png;base64,...)
#
# Fuente: https://www.legislatura.gov.ar/seccion/composicion-actual.html
#
# Por eso son importantes las votaciones de Diputados y Legisladores, dado que estos últimos son los encargados de sancionar el presupuesto de la Ciudad. En las últimas elecciones PASO estos fueron los resultados:
#
# ![image.png](data:image/png;base64,...)
#
# Fuente: https://www.buenosaires.gob.ar/ministeriodegobierno/reformapoliticayelectoral/elecciones-en-la-ciudad/resultados-elecciones-2021

# %% [markdown]
# ## 💸**Variable Nominal vs Variable Real**:
# ¿Cómo comparar Presupuestos anuales en economías de alta inflación? Para analizar y poder comparar los presupuestos, elegimos dos enfoques diferentes para:
# - **IPC CABA**: el Índice de Precios al Consumidor de CABA es una medida para los precios de los bienes y servicios adquiridos por un consumidor típico en la ciudad. Se calcula a en función a una canasta (grupo de artículos según importancia/ponderación de consumo) en relación con un año base (2011) para comparar su incremento con otros años.  El IPC es una medida de nivel de precios (la tasa de inflación es el cambio porcentual de los precios con respecto al año o mes anterior).
# Fuente: https://www.estadisticaciudad.gob.ar/eyc/?p=27386
#
#   Con el IPC promedio anual, deflactamos la serie, tomando como año base 2020 y así comparar todo en una misma moneda actualizada por inflación.
#
#   ![image.png](data:image/png;base64,...)
#
# - **Dólar Tipo de Cambio**: si bien tomar el promedio de TC por año nos trae una mejor conceptualización de la realidad dado que el peso argentino en valores nominales no podría compararse a lo largo del tiempo, no sería del todo correcto. En este sentido, el nivel general de precios y el TC no van necesariamente anclados. Por ejemplo, para 2017 el nivel general de precios fue mayor, y lo contrario sucede para 2019 y 2020.
#
#   Fuente: http://www.bcra.gob.ar/PublicacionesEstadisticas/Tipos_de_cambios.asp

# %% [markdown]
# ##🔍**Descripción técnica**
# El diagrama presenta las herramientas utilizadas y sus relaciones.
#
# ![Examen Bimestre 3 - Tecnologias-3.png](data:image/png;base64,...)

# %% [markdown]
# #⚙ **Instalación, configuración e inicialización de Spark**

# %%
#Instalación de JDK, Hadoop y Spark
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://downloads.apache.org/spark/spark-2.4.8/spark-2.4.8-bin-hadoop2.7.tgz
# !tar xf spark-2.4.8-bin-hadoop2.7.tgz
# !pip install -q findspark

#definición de variables de entorno
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-2.4.8-bin-hadoop2.7"

#inicio de sesión spark
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()

# %% [markdown]
# ---
# #🚀**ETL - Extraccción, Transformación y Carga**

# %% [markdown]
# ##**Tablas de presupuestos anuales**
# Se toman los datos de los presupuestos sancionados desde 2017 a 2021 de cinco archivos CSV publicados en la plataforma Buenos Aires Data del Gobierno de CABA.
#
# Los registros se almacenan en dataframes Spark. Se crean también las vistas temporales Spark para utilizarlas en el procesamiento mediante SQL.

# %%
from pyspark import SparkFiles

columnas_presu = ["geo","fun_desc","sancion"]

#Presupuesto CABA 2017
#separador ;
csv2017 = 'https://raw.githubusercontent.com/agroideas/diplo_uade/main/presupuesto-sancionado-2017.csv'
spark.sparkContext.addFile(csv2017)
df_2017 = spark.read.option("delimiter",";").csv(SparkFiles.get("presupuesto-sancionado-2017.csv"), inferSchema=True, header=True).select(columnas_presu)
df_2017.createOrReplaceTempView("presu2017")

#Presupuesto CABA 2018
#separador ;
csv2018 = 'https://raw.githubusercontent.com/agroideas/diplo_uade/main/presupuesto-sancionado-2018.csv'
spark.sparkContext.addFile(csv2018)
df_2018 = spark.read.option("delimiter",";").csv(SparkFiles.get("presupuesto-sancionado-2018.csv"), inferSchema=True, header=True).select(columnas_presu)
df_2018.createOrReplaceTempView("presu2018")

#Presupuesto CABA 2019
#separador ,
csv2019 = 'https://raw.githubusercontent.com/agroideas/diplo_uade/main/presupuesto-sancionado-2019.csv'
spark.sparkContext.addFile(csv2019)
df_2019 = spark.read.csv(SparkFiles.get("presupuesto-sancionado-2019.csv"), inferSchema=True, header=True).select(columnas_presu)
df_2019.createOrReplaceTempView("presu2019")

#Presupuesto CABA 2020
#separador ,
csv2020 = 'https://raw.githubusercontent.com/agroideas/diplo_uade/main/presupuesto-sancionado-2020.csv'
spark.sparkContext.addFile(csv2020)
df_2020 = spark.read.csv(SparkFiles.get("presupuesto-sancionado-2020.csv"), inferSchema=True, header=True).select(columnas_presu)
df_2020.createOrReplaceTempView("presu2020")

#Presupuesto CABA 2021
#separador ,
csv2021 = 'https://raw.githubusercontent.com/agroideas/diplo_uade/main/presupuesto-sancionado-2021.csv'
spark.sparkContext.addFile(csv2021)
df_2021 = spark.read.csv(SparkFiles.get("presupuesto-sancionado-2021.csv"), inferSchema=True, header=True).select(columnas_presu)
df_2021.createOrReplaceTempView("presu2021")

#registros de cada dataframe
print(f"Presupuesto 2017: {df_2017.count()} registros")
print(f"Presupuesto 2018: {df_2018.count()} registros")
print(f"Presupuesto 2019: {df_2019.count()} registros")
print(f"Presupuesto 2020: {df_2020.count()} registros")
print(f"Presupuesto 2021: {df_2021.count()} registros")
# Out:
# Presupuesto 2017: 41445 registros
# Presupuesto 2018: 36011 registros
# Presupuesto 2019: 34392 registros
# Presupuesto 2020: 35043 registros
# Presupuesto 2021: 31745 registros

# %% [markdown]
# ##**Análisis Columnas de Datasets Presupuesto**
#
# - Descripción de todas las columnas del dataset en [acá](https://github.com/maiabuzarquis/ipc_csv_diplouade/blob/main/Descripci%C3%B3n%20Columnas%20Dataset%20-%20Presupuesto%20csv.csv)
# - Para nuestro análisis sólo nos quedaremos con las siguientes columnas:
#
#   1. **Fun_desc**	(string):	Es el nivel de cuentas dentro de la clasificación del gasto por Finalidad y Función que permite examinar en el tiempo las tendencias del gasto para las funciones generales del Gobierno.
#   2. **Geo_desc**	(string):	La clasificación por ubicación geográfica establece la distribución espacial de las transacciones económico-financieras que realizan los organismos del Sector Público - Comunas.
#   3. **Sancion**	(integer):	Es el crédito aprobado por Ley de Presupuesto para cada ejercicio por La Legislatura de la Ciudad Autónoma de Buenos Aires y promulgado mediante decreto por el Poder Ejecutivo. Moneda en valores nominales.
#
# - Nuevas columnas agregadas:
#   1. **indice**: coeficiente deflactor utilizando IPC CABA
#   2. **constante**: serie deflactada, moneda llevada a 2020
#   3. **usd**: TC
#   4. **dolares**: moneda nominal dividido TC

# %% [markdown]
# ##**Tablas adicionales**
# Para el análisis se utilizan tres tablas adicionales, también tomadas desde archivos CSV y almacenadas en dataframes Spark. Se crean las vistas temporales.
# - **Barrios por comuna** (Fuente: CABA)
# - **Población por comuna** (Fuente: CABA)
# - **IPC CABA promedio por año y TC promedio por año** (Fuente: elaboración propia según Centro de Estadística y Censos del Gobierno de la Ciudad de Buenos Aires y BCRA, citadas anteriormente)

# %%
#barrios por comuna
#separador ,
csv_barrios = 'https://raw.githubusercontent.com/agroideas/diplo_uade/main/comunas.csv'
spark.sparkContext.addFile(csv_barrios)
df_barrios = spark.read.csv(SparkFiles.get("comunas.csv"), inferSchema=True, header=True).select("comunas","barrios")
df_barrios.createOrReplaceTempView("barrios")

#poblacion por comuna, datos de 2020
#separador ;
csv_poblacion = 'https://raw.githubusercontent.com/agroideas/diplo_uade/main/poblacion_2020.csv'
spark.sparkContext.addFile(csv_poblacion)
df_poblacion = spark.read.option("delimiter",";").csv(SparkFiles.get("poblacion_2020.csv"), inferSchema=True, header=True).select("comuna","total","superficie")
df_poblacion.createOrReplaceTempView("poblacion")

#tabla IPC y TC
csv_ipc_tc = 'https://github.com/maiabuzarquis/ipc_csv_diplouade/raw/main/tc_ipc_csv.csv'
spark.sparkContext.addFile(csv_ipc_tc)
df_ipc_tc = spark.read.option("delimiter",",").csv(SparkFiles.get("tc_ipc_csv.csv"), inferSchema=True, header=True)
df_ipc_tc.createOrReplaceTempView("csv_ipc_tc")

# %% [markdown]
# ## 📍 **Barrios por Comuna**
# ![image.png](data:image/png;base64,...)

# %%
df_poblacion.show()
df_barrios.show()
df_ipc_tc.show()
# Out:
# +------+------+----------+
# |comuna| total|superficie|
# +------+------+----------+
# |     1|256405|   17,7649|
# |     2|149430|   6,30245|
# |     3|193276|     6,385|
# |     4|240100|    21,669|
# |     5|187518|   6,65905|
# |     6|185456|     6,851|
# |     7|241861|   12,4276|
# |     8|228953|    22,292|
# |     9|171264|    16,506|
# |    10|170592|   12,6569|
# |    11|190076|   14,1193|
# |    12|214777|   15,5676|
# |    13|236358| 14,651746|
# |    14|227115|   15,8465|
# |    15|182465| 14,322713|
# +------+------+----------+
#
# +-------+--------------------+
# |comunas|             barrios|
# +-------+--------------------+
# |    2.0|            RECOLETA|
# |    6.0|           CABALLITO|
# |   10.0|FLORESTA - MONTE ...|
# |   11.0|VILLA DEL PARQUE ...|
# |   12.0|COGHLAN - SAAVEDR...|
# |   14.0|             PALERMO|
# |   15.0|AGRONOMIA - CHACA...|
# |   13.0|BELGRANO - COLEGI...|
# |    4.0|BARRACAS - BOCA -...|
# |    5.0|     ALMAGRO - BOEDO|
# ...

# %% [markdown]
# ---
# #💰 **Tabla de valores de conversión de monedas**
# Preparación de una vista temporal con el cálculo de los índices de actualización a moneda 2021 por IPC y el valor del dólar oficial al mes de sanción del presupuesto para cada uno de los cinco años.

# %%
monedas = spark.sql("SELECT Anio+1 as periodo, (select IPC_General_Promedio from csv_ipc_tc where Anio=2020)/IPC_General_Promedio as indice, TC_oficial_promedio_anual as usd from csv_ipc_tc")
monedas.createOrReplaceTempView("monedas")
monedas.show()
# Out:
# +-------+------------------+-----+
# |periodo|            indice|  usd|
# +-------+------------------+-----+
# |   2017| 3.541360858504634|14.78|
# |   2018|2.7759924818923625|16.57|
# |   2019|2.0723281201875365|28.09|
# |   2020|1.3713370170750485|48.24|
# |   2021|               1.0|70.59|
# |   2022|0.7606710380866244|93.39|
# +-------+------------------+-----+

# %% [markdown]
# # 📑 **Datasets para análisis de presupuestos anuales**
# En esta sección se desarrolla la selección de los campos de cada período de presupuesto combinando con los valores de las tablas adicionales para el análisis.

# %%
#presupuesto 2017
p2017 = spark.sql("SELECT 2017 as periodo, b.barrios, pre.fun_desc, replace(pre.sancion,'.','') sancion, p.total, replace(p.superficie,',','.') superficie, \
(select indice from monedas where periodo=2017) as indice, \
(select usd from monedas where periodo=2017) as usd \
from presu2017 pre \
left join barrios b on pre.geo=comunas \
left join poblacion p on pre.geo=comuna")

# %%
#presupuesto 2018
p2018 = spark.sql("SELECT 2018 as periodo, b.barrios, pre.fun_desc, replace(pre.sancion,'.','') sancion, p.total, replace(p.superficie,',','.') superficie, \
(select indice from monedas where periodo=2018) as indice, \
(select usd from monedas where periodo=2018) as usd \
from presu2018 pre \
left join barrios b on pre.geo=comunas \
left join poblacion p on pre.geo=comuna")

# %%
#presupuesto 2019
p2019 = spark.sql("SELECT 2019 as periodo, b.barrios, pre.fun_desc, replace(pre.sancion,',','') sancion, p.total, replace(p.superficie,',','.') superficie, \
(select indice from monedas where periodo=2019) as indice, \
(select usd from monedas where periodo=2019) as usd \
from presu2019 pre \
left join barrios b on pre.geo=comunas \
left join poblacion p on pre.geo=comuna")

# %%
#presupuesto 2020
p2020 = spark.sql("SELECT 2020 as periodo, b.barrios, pre.fun_desc, replace(pre.sancion,'.','') sancion, p.total, replace(p.superficie,',','.') superficie, \
(select indice from monedas where periodo=2020) as indice, \
(select usd from monedas where periodo=2020) as usd \
from presu2020 pre \
left join barrios b on pre.geo=comunas \
left join poblacion p on pre.geo=comuna")

# %%
#presupuesto 2021
p2021 = spark.sql("SELECT 2021 as periodo, b.barrios, pre.fun_desc, replace(pre.sancion,'.','') sancion, p.total, replace(p.superficie,',','.') superficie, \
(select indice from monedas where periodo=2021) as indice, \
(select usd from monedas where periodo=2021) as usd \
from presu2021 pre \
left join barrios b on pre.geo=comunas \
left join poblacion p on pre.geo=comuna")

# %%
#concatenación de los cinco presupuestos en un dataframe
presupuesto = p2017.union(p2018).union(p2019).union(p2020).union(p2021)

# %% [markdown]
# #📝**Cálculo de valores e indicadores**
# El dataframe Spark con los presupuestos unificados se convierte a Pandas para procesarlo.
#
# Se agregan columnas con el cálculo del presupuesto sancionado en moneda constante del año 2021 y su valor en dólares oficiales del mes de sanción.
#
# Se calcula también el presupuesto en moneda constante por habitante para cada comuna.

# %%
#convierte dataframe spark a pandas 
# presupuesto: dataframe spark
# total: dataframe pandas
total = presupuesto.toPandas()
#ajuste de tipos de datos
total = total.astype({'sancion': 'float','superficie':'float'})
#cálculo de presupuesto sancionado en moneda 2021
total['constante'] = total['sancion']*total['indice']
#cálculo de presupuesto sancionado en dólares
total['dolares'] = total['sancion']/total['usd']
#cálculo de presupuesto asignado por habitante, moneda 2021
total['por_habitante'] = total['constante']/total['total']

# %% [markdown]
# ---
# #💾**Persistencia**
# El presupuesto unificado para los cinco años con el agregado de los valores calculados se almacena en una base de datos MySQL.

# %%
#preparacion de modulos y conexion a mysql
# !pip install mysql.connector
import pandas as pd
import mysql.connector
from sqlalchemy import create_engine

#conexióm
engine = create_engine('mysql+mysqlconnector://uade:Uad3_Diplo2021#@107.191.102.204:3306/uade', echo=False)

#guardado en la base
total.to_sql(name='presupuesto', con=engine, if_exists = 'replace',chunksize=10000, index=False)
# Out:
# ...
#      |████████████████████████████████| 11.9 MB 132 kB/s
# ...
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp37-cp37m-linux_x86_64.whl size=247965 sha256=92edc5284cb87735efada343faf3ac3979333bec590f854b2e1b02728c3707e1
#   Stored in directory: /root/.cache/pip/wheels/42/2f/c3/692fc7fc1f0d8c06b9175d94f0fc30f4f92348f5df5af1b8b7
# Successfully built mysql.connector
# ...

# %% [markdown]
# # 🖋 **Conclusiones**

# %%
#Análisis Macro, totales por período en moneda nominal, moneda real y dolares
print('Análisis Macro en Miles de Millones \n')
total_periodo = total.groupby(['periodo']).agg({'sancion':'sum','constante': 'sum','dolares': 'sum'})
total_periodo_m = (total_periodo / 1000000000).round(2)
total_periodo_m
# Out:
# Análisis Macro en Miles de Millones
#          sancion  constante  dolares
# periodo
# 2017      178.81     633.22    12.10
# 2018      221.07     613.69    13.34
# 2019      327.08     677.82    11.64
# 2020      480.98     659.59     9.97
# 2021      612.80     612.80     8.68

# %%
import seaborn as sns
dfcorriente = total_periodo_m.groupby(['periodo']).agg({'sancion': 'sum'}).reset_index()
figure2 = sns.catplot(x='periodo', y='sancion', kind='bar', data=dfcorriente, color='skyblue')
(figure2.set_axis_labels ('\nPeríodo\n', '\nTotal Presupuesto Nominal en Miles de Millones\n')
  .set(ylim=(150,700)))

# %%
dfconstante = total_periodo_m.groupby(['periodo']).agg({'constante': 'sum'}).reset_index()
figure1 = sns.catplot(x='periodo', y='constante', kind='bar', data=dfconstante, color='indianred')
(figure1.set_axis_labels ('\nPeríodo\n', '\nTotal Presupuesto Real en Miles de Millones\n')
  .set(ylim=(600,680)))

# %%
dfdolares = total_periodo_m.groupby(['periodo']).agg({'dolares': 'sum'}).reset_index()
figure3 = sns.catplot(x='periodo', y='dolares', kind='bar', data=dfdolares, color='seagreen')
(figure3.set_axis_labels ('\nPeríodo\n', '\nTotal Presupuesto en USD en Miles de Millones\n')
  .set(ylim=(8,15)))

# %% [markdown]
# ## 📚 **Bibliografía**
# - Presupuesto 2021: Ley N° 6384/2020 - Promulgación Presupuesto 2021 – Aprobado 10/12/2020
#
#   https://boletinoficial.buenosaires.gob.ar/normativaba/norma/537849
#
# - Presupuesto 2020: N° 6.281 , 5 de diciembre de 2019
#
#   https://www.buenosaires.gob.ar/sites/gcaba/files/1_-_ley_6281_cifras_conforme_a_la_ley_aprobada_en_la_legislatura.pdf
#
# - Presupuesto 2019: Ley N° 6068 de Presupuesto para el ejercicio 2019 – Aprobado 29/11/2018
#
#   https://www.buenosaires.gob.ar/haciendayfinanzas/presupuesto-2019
#
# - Presupuesto 2018: Ley N° 5.915 (Cifras conforme a las modificaciones realizadas por la Legislatura) Aprobado 30/11/2017
#
#   https://www.buenosaires.gob.ar/economiayfinanzas/presupuesto/presupuesto-2018
#
# - Presupuesto 2017: Ley N° 5.724 (Cifras conforme a las modificaciones realizadas por la Legislatura) Arpobado 1/12/2016
#
#   https://www.buenosaires.gob.ar/haciendayfinanzas/presupuesto-2017
